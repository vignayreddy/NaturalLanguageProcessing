# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\vigna\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Tokenization Example

# %%
corpus = """Hello Welcome ,to Krish naik nlp tutorials..
Please do watch the entire. course to become expert in nlp
"""
print(corpus)
# Out:
# Hello Welcome ,to Krish naik nlp tutorials..
# Please do watch the entire. course to become expert in nlp

# %%
##Tokenization 
## Sentence-->Paragraphs
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)
documents
# Out:
# ['Hello Welcome ,to Krish naik nlp tutorials..',
#  'Please do watch the entire.',
#  'course to become expert in nlp']

# %%
from nltk.tokenize import word_tokenize
for sent in documents:
    val = word_tokenize(sent)
    print(val)
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'naik', 'nlp', 'tutorials', '..']
# ['Please', 'do', 'watch', 'the', 'entire', '.']
# ['course', 'to', 'become', 'expert', 'in', 'nlp']
